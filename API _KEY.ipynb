# %% [markdown]
# <a href="https://colab.research.google.com/github/ravikumarsirasani/Agentic-AI-2026/blob/main/API%20_KEY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Reverse String

# %%
# !pip install anthropic
