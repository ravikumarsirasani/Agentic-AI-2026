# %% [markdown]
# <a href="https://colab.research.google.com/github/ravikumarsirasani/Agentic-AI-2026/blob/main/Python_keywords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello workld")
# Out:
# hello workld

# %%
# prompt: write python program to display hello world and give the out put

print("Hello World")
# Output: Hello World

# %%
import keyword

# Get sorted list of keywords for your Python version
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
