# %% [markdown]
# <a href="https://colab.research.google.com/github/ravikumarsirasani/Agentic-AI-2026/blob/main/Token_Count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello workld")
# Out:
# hello workld

# %%
# prompt: write python program to display hello world and give the out put

print("Hello World")
# Output: Hello World

# %%
import keyword

# Get sorted list of keywords for your Python version
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
def count_tokens_and_chars(text):
    # Tokenize by splitting on whitespace
    tokens = text.split()
    token_count = len(tokens)
    char_count = len(text)
    return token_count, char_count

# Get input from the user
input_string = input("Enter some text: ")

# Calculate token and character counts
tokens, chars = count_tokens_and_chars(input_string)

# Display the results
print(f"Token Count: {tokens}")
print(f"Character Count: {chars}")
# Out:
# Enter some text: I am ravikumar Sirasani
# Token Count: 4
# Character Count: 23
