# %% [markdown]
# <a href="https://colab.research.google.com/github/ravikumarsirasani/Agentic-AI-2026/blob/main/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Agentic AI")
# Out:
# Welcome to Agentic AI
